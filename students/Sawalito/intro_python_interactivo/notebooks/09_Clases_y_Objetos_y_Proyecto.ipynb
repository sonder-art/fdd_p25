# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sonder-art/fdd_p25/blob/main/professor/intro_python_interactivo/notebooks/09_Clases_y_Objetos_y_Proyecto.ipynb)

# %% [markdown]
# # Clases y Objetos + Mini Proyecto
#
# - Definir clases, atributos y métodos
# - Inspección: `type`, `dir`, `vars`, `__dict__`
# - Mini proyecto: procesar registros (listas/dicts), sumarizar con funciones, formatear con f-strings
#
# Entrega: ejecuta todas las celdas y describe 3 hallazgos.

# %% [markdown]
# ## Clases básicas y atributos
#
# Define una clase con `__init__` para inicializar atributos; métodos operan sobre `self`.

# %%
class Persona:
    def __init__(self, nombre: str, edad: int):
        self.nombre = nombre
        self.edad = edad
    def saludar(self) -> str:
        return f"Hola soy {self.nombre} y tengo {self.edad} años"

p = Persona("Ana", 21)
print(p.saludar())
print("attrs:", vars(p))
# Out:
# Hola soy Ana y tengo 21 años
# attrs: {'nombre': 'Ana', 'edad': 21}

# %% [markdown]
# ## (Opcional) dataclasses
#
# Reducen el código repetitivo para clases de datos.

# %%
from dataclasses import dataclass

@dataclass
class Punto:
    x: int
    y: int

q = Punto(2,3)
print(q)
# Out:
# Punto(x=2, y=3)

# %% [markdown]
# ## Mini proyecto (guía)
#
# - Datos: lista de dicts con registros (nombre, edad, ciudad).
# - Tareas: filtrar por ciudad, calcular promedio de edad, formatear reporte con f-strings.
# - Extiende: maneja errores (registros incompletos) y agrega una función de validación.

# %%
from statistics import mean

class DatoInvalidoError(ValueError):
    pass


class Personas():
    def __init__(self,lista : list):
        self.lista = lista
        self.lista_limpia = self.validar_registros()

    def validar_registros(self):
        listal = []
        campos = ['nombre','edad','ciudad']

        for i in self.lista:
            if not all(campo in i for campo in campos):
                raise DatoInvalidoError(f"Capturado: Error el registro {i} incompleto")
            listal.append(i)
        return listal
    
    def filtrar_cidudad(self, ciudad : str):
        personas = [ x for x in self.lista_limpia if x['ciudad'] == ciudad]
        for i in personas:
            print(f"nombre: {i['nombre']:^10} \n ciudad: {i['ciudad']:^10} \n edad: {i['edad']:^10}")

    def calcular_promedio(self):
        try:
            media = mean([i['edad'] for i in self.lista_limpia])
            print(f"El promedio de la edad es {media}")
        except Exception as e:
            print("Capturado: ",e)   

lista = [{"nombre": "Ana", "edad": 12, "ciudad": "Madrid"},
    {"nombre": "Luis", "edad": 14, "ciudad": "Barcelona"},
    {"nombre": "Zoe", "edad": 4, "ciudad": "Madrid"}]
lista = []
p = Personas(lista=lista)
p.calcular_promedio()
# Out:
# Capturado:  mean requires at least one data point

# %% [markdown]
# ## Atributos de clase vs de instancia
#
# - Atributo de clase: compartido por todas las instancias.
# - Atributo de instancia: propio de cada objeto.
# - Evita mutar atributos de clase que sean contenedores a menos que lo necesites.

# %%
class Contador:
    total = 0   # atributo de clase
    def __init__(self):
        self.cuenta = 0  # atributo de instancia

c1 = Contador()
c2 = Contador()
Contador.total += 1
c1.cuenta += 1
print("class total:", Contador.total, "c1:", c1.cuenta, "c2:", c2.cuenta)
# Out:
# class total: 1 c1: 1 c2: 0

# %% [markdown]
# ## `__repr__` y `__str__`
#
# - `__repr__`: representación para desarrolladores (no ambigua).
# - `__str__`: representación legible para usuarios (si no está, usa `__repr__`).

# %%
class Punto2:
    def __init__(self, x, y):
        self.x = x; self.y = y
    def __repr__(self):
        return f"Punto2(x={self.x}, y={self.y})"
    def __str__(self):
        return f"({self.x}, {self.y})"

p = Punto2(1,2)
print(repr(p))
print(str(p))
# Out:
# Punto2(x=1, y=2)
# (1, 2)

# %% [markdown]
# ## `@property` (getters/setters pythonic)
#
# Convierte métodos en atributos calculados y valida al asignar sin escribir `getX/setX` explícitos.

# %%
class Cuenta:
    def __init__(self, saldo: float):
        self._saldo = saldo

    @property
    def saldo(self) -> float:
        return self._saldo

    @saldo.setter
    def saldo(self, valor: float) -> None:
        if valor < 0:
            raise ValueError("Saldo no puede ser negativo")
        self._saldo = valor

c = Cuenta(100)
print(c.saldo)
c.saldo = 150
print(c.saldo)
# Out:
# 100
# 150
