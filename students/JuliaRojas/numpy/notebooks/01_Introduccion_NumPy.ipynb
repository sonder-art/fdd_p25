# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/sonder-art/fdd_p25/blob/main/professor/numpy/notebooks/01_Introduccion_NumPy.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 01 — Introducción a NumPy
#
# Objetivo: comprender qué es NumPy, por qué usar `ndarray` y cómo se compara con listas de Python.
#
# - ¿Qué es un `ndarray`?
# - Ventajas (vectorización, memoria contigua, broadcasting)
# - Import básico y versión
# - Primer array y su `shape`
# - Comparación con listas

# %%
# mala practica deberian instalarlo con requirements, pero es para colab
# !pip install numpy matplotlib ipykernel
# Out:
# Collecting numpy
#   Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: ipykernel in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (7.0.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.1 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (9.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /home/julia/Documents/GitHub/TereasBases/.venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 21.7 MB/s  0:00:00 eta 0:00:01
# Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 25.3 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 22.5 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.4 MB/s  0:00:00
# Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 28.7 MB/s  0:00:00 eta 0:00:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [matplotlib]8 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.3.4 pillow-12.0.0 pyparsing-3.2.5

# %%
import numpy as np
np.__version__

# %%
# Primer ndarray y shape
arr = np.array([1, 2, 3, 4, 5])
arr, arr.shape

# %% [markdown]
# ## Listas vs ndarrays (coste y operaciones)
# - Listas: objetos heterogéneos, operaciones elemento a elemento con bucles
# - NumPy: vectorización y operaciones en bloque

# %%
# Comparación básica: multiplicar por 2
lista = list(range(10))
arr = np.arange(10)

lista_doble = [x*2 for x in lista]
arr_doble = arr * 2

lista_doble, arr_doble
